# %%
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# %%
df = pd.read_csv('tel_churn.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0           29.85         29.85      0
# 1           1              0           56.95       1889.50      0
# 2           2              0           53.85        108.15      1
# 3           3              0           42.30       1840.75      0
# 4           4              0           70.70        151.65      1
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0           True        False       False         True           True  ...
# 1          False         True        True        False           True  ...
# 2          False         True        True        False           True  ...
# 3          False         True        True        False           True  ...
# 4           True        False        True        False           True  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0           True
# 1              0           56.95       1889.50      0          False
# 2              0           53.85        108.15      1          False
# 3              0           42.30       1840.75      0          False
# 4              0           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0        False       False         True           True           False  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True        True        False           True           False  ...
# 4        False        True        False           True           False  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
# creating x and y variables

x = df.drop('Churn', axis=1)
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85           True        False
# 1                 0           56.95       1889.50          False         True
# 2                 0           53.85        108.15          False         True
# 3                 0           42.30       1840.75          False         True
# 4                 0           70.70        151.65           True        False
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50          False         True
# 7028              0          103.20       7362.90           True        False
# 7029              0           29.60        346.45           True        False
# 7030              1           74.40        306.60          False         True
# 7031              0          105.65       6844.50          False         True
#
# ...

# %%
y = df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ### **Decision Tree Classifier**

# %%
model_dt = DecisionTreeClassifier(criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)

# %%
model_dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred = model_dt.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], shape=(1407,))

# %% [markdown]
# ##### -> we want to compare predicted y values to actual y values

# %%
model_dt.score(x_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# #### -> this shows full accuracy

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85      1034
#            1       0.59      0.42      0.49       373
#
#     accuracy                           0.77      1407
#    macro avg       0.70      0.66      0.67      1407
# weighted avg       0.75      0.77      0.76      1407

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[926 108]
#  [215 158]]

# %% [markdown]
# #### **SMOTEENN** - class to perform over-sampling using SMOTE and cleaning using ENN.
#
# ##### **SMOTEENN is a data resampling technique used to handle class imbalance by combining oversampling and undersampling methods.**

# %%
sm = SMOTEENN()
x_resampled, y_resampled = sm.fit_resample(x,y)

# %%
xr_train, xr_test, yr_train, yr_test = train_test_split(x_resampled,y_resampled, test_size = 0.2)

# %%
model_dt_smote = DecisionTreeClassifier(criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)

# %%
model_dt_smote.fit(xr_train, yr_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred_smote = model_dt_smote.predict(xr_test)

# %%
print(classification_report(yr_test, y_pred_smote, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       522
#            1       0.92      0.96      0.94       662
#
#     accuracy                           0.93      1184
#    macro avg       0.93      0.93      0.93      1184
# weighted avg       0.93      0.93      0.93      1184

# %%
print(confusion_matrix(yr_test, y_pred_smote))
# Out:
# [[467  55]
#  [ 25 637]]

# %% [markdown]
# ### **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators=100, criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)
model_rf.fit(x_train, y_train)
y_pred_rf = model_rf.predict(x_test)

# %%
print(classification_report(y_test, y_pred_rf, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1034
#            1       0.67      0.48      0.56       373
#
#     accuracy                           0.80      1407
#    macro avg       0.75      0.70      0.72      1407
# weighted avg       0.79      0.80      0.79      1407

# %%
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# [[945  89]
#  [193 180]]

# %%
sm =SMOTEENN()
x_resampled, y_resampled = sm.fit_resample(x,y)

# %%
xr_train, xr_test, yr_train, yr_test = train_test_split(x_resampled, y_resampled, test_size = 0.2)

# %%
model_smote_rf = RandomForestClassifier(n_estimators=100, criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)

# %%
model_smote_rf.fit(xr_train, yr_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred_smote_rf = model_smote_rf.predict(xr_test)

# %%
print(classification_report(yr_test, y_pred_smote_rf, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       506
#            1       0.94      0.96      0.95       659
#
#     accuracy                           0.94      1165
#    macro avg       0.94      0.94      0.94      1165
# weighted avg       0.94      0.94      0.94      1165

# %%
print(confusion_matrix(yr_test, y_pred_smote_rf))
# Out:
# [[462  44]
#  [ 26 633]]

# %% [markdown]
# ## **_Logistic Regression_**

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression(max_iter=5000)

log_model.fit(xr_train, yr_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
y_pred_log = log_model.predict(xr_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Logistic Regression Accuracy:", accuracy_score(yr_test, y_pred_log))
print(classification_report(yr_test, y_pred_log))
# Out:
# Logistic Regression Accuracy: 0.9467811158798283
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       506
#            1       0.95      0.95      0.95       659
#
#     accuracy                           0.95      1165
#    macro avg       0.95      0.95      0.95      1165
# weighted avg       0.95      0.95      0.95      1165

# %%
print(confusion_matrix(yr_test, y_pred_log))
# Out:
# [[475  31]
#  [ 31 628]]

# %% [markdown]
# ## **Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()

svm_model.fit(xr_train, yr_train)
# Out:
# SVC()

# %%
y_pred_svm = svm_model.predict(xr_test)

# %%
print("SVM Accuracy:", accuracy_score(yr_test, y_pred_svm))
print(classification_report(yr_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.7484978540772532
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73       506
#            1       0.81      0.72      0.76       659
#
#     accuracy                           0.75      1165
#    macro avg       0.75      0.75      0.75      1165
# weighted avg       0.76      0.75      0.75      1165

# %%
print(confusion_matrix(yr_test, y_pred_svm))
# Out:
# [[398 108]
#  [185 474]]

# %% [markdown]
# #### **For saving the model**

# %%
import pickle

# %%
filename = 'model.sav'

# %%
pickle.dump(model_smote_rf, open(filename, 'wb'))

# %%
load_model = pickle.load(open(filename, 'rb'))

# %%
load_model.score(xr_test, yr_test)
# Out:
# 0.9399141630901288

# %% [markdown]
# ####                   **it is shown 93.99% accuracy**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

results = []

# Decision Tree
results.append([
    "Decision Tree",
    accuracy_score(yr_test, y_pred_smote),
    precision_score(yr_test, y_pred_smote),
    recall_score(yr_test, y_pred_smote),
    f1_score(yr_test, y_pred_smote)
])

# Random Forest
results.append([
    "Random Forest",
    accuracy_score(yr_test, y_pred_rf),
    precision_score(yr_test, y_pred_rf),
    recall_score(yr_test, y_pred_rf),
    f1_score(yr_test, y_pred_rf)
])

# Logistic Regression
results.append([
    "Logistic Regression",
    accuracy_score(yr_test, y_pred_log),
    precision_score(yr_test, y_pred_log),
    recall_score(yr_test, y_pred_log),
    f1_score(yr_test, y_pred_log)
])

# SVM
results.append([
    "SVM",
    accuracy_score(yr_test, y_pred_svm),
    precision_score(yr_test, y_pred_svm),
    recall_score(yr_test, y_pred_svm),
    f1_score(yr_test, y_pred_svm)
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[145], line 8
#       4
#       5 # Decision Tree
#       6 results.append([
#       7     "Decision Tree",
# ----> 8     accuracy_score(yr_test, y_pred_smote),
#       9     precision_score(yr_test, y_pred_smote),
#      10     recall_score(yr_test, y_pred_smote),
#      11     f1_score(yr_test, y_pred_smote)
#
# File c:\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
# ...
